# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ppscore as pps
import seaborn as sns

# %%
data = pd.read_csv('formiga (1).csv',sep = ';')
del data['Unnamed: 0']
df = pd.DataFrame(data)
df
# Out:
#         att1      att2      att3      att4      att5      att6      att7  \
# 0  -0.219477 -0.160522 -0.587900 -0.125353 -0.128844  9.226784 -0.308035
# 1   9.540726  5.970428 -0.307741  9.246844 -0.118710 -0.405239 -0.147114
# 2  -0.347754 -0.203426 -0.590067 -0.088842 -0.052566  0.423246 -0.455932
# 3  -0.337242 -0.200889 -0.602060 -0.089376 -0.061314  9.441957 -0.419836
# 4  -0.145289 -0.103841 -0.530669 -0.129011 -0.118806 -0.121095 -0.327594
# 5  -0.010550 -0.059484 -0.281498 -0.171340 -0.089909 -0.065502 -0.235824
# 6  -0.110698 -0.117333 -0.394156 -0.027219  5.409018 -0.061731 -0.353106
# 7  -0.014524 -0.052675 -0.338924 -0.150171 -0.072345 -0.107287 -0.241256
# 8  -0.111821 -0.098542 -0.393619 -0.015923 -0.161151 -0.075721 -0.356547
# 9   9.954644  9.229412 -0.339451 -0.165156 -0.107164 -0.108834 -0.221969
# 10 -0.089909 -0.010550 -0.355561 -0.202732 -0.202732 -0.366532 -0.311580
# 11  9.741285 -0.031361 -0.431798 -0.236322 -0.229639 -0.337242 -0.325751
# ...

# %%
#1 significa que a coluna x pode prever perfeitamente a coluna y, 
#pps.score(df, 'att1', 'att3')
#pps.matrix(df)
df_matrix = pps.matrix(df)

# %%
plt.figure(figsize = (12, 12))
sns.heatmap(df_matrix, vmin=0, vmax=1, cmap="Blues", linewidths=0.1, annot=True)
